# %% [markdown]
# # Hamoye Intermship stage A tag along project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Question 11

# %%
data.groupby('Item').sum()
# Out:
#                           Area Code  Item Code  Element Code      Y2014  \
# Item
# Alcohol, Non-Food             38447     752497       1515090    2403.00
# Alcoholic Beverages           75016    1649136       2171381  102410.11
# Animal Products               18060     397035         90990   11935.65
# Animal fats                   85279    1882494       2567303  209460.54
# Apples and products           69280    1352989       1920418    9499.23
# Aquatic Animals, Others       47420     966381       1139179      14.55
# Aquatic Plants                51178    1057275       1278386     507.29
# Aquatic Products, Other       52570    1160712       1320249     519.62
# Bananas                       68496    1338880       1894890   53267.31
# Barley and products           76321    1432410       2243002   25384.66
# Beans                         78001    1476680       2263509   19207.68
# Beer                          65975    1314720       1813728   41879.92
# ...

# %% [markdown]
# The total sum of Animal Fat produced in 2014 and 2017 is 209460.54 and 269617.53 respectively

# %% [markdown]
# ## Question 12

# %%
mean_data = data['Y2015'].mean()
standard_dev = data['Y2015'].std()

print("The mean across the whole dataset for the year 2015 is :", round(mean_data, 3))
print("The standard deviation across the whole dataset for the year 2015 is :", round(standard_dev, 3))
# Out:
# The mean across the whole dataset for the year 2015 is : 135.236
# The standard deviation across the whole dataset for the year 2015 is : 1603.404

# %% [markdown]
# ## Question 13

# %%
total_null = data['Y2016'].isnull().sum()
per_tNull = data['Y2016'].isnull().sum() * 100 / len(data)

print("The total number and of missing data in 2016 is:", total_null)
print("the total percentage of missing data in 2016 is:",round(per_tNull,2), "to 2 decimal places")
# Out:
# The total number and of missing data in 2016 is: 1535
# the total percentage of missing data in 2016 is: 2.52 to 2 decimal places

# %% [markdown]
# ## Question 14

# %%
sns.heatmap(data = data.corr())

# %% [markdown]
# ## Question 15

# %%
data.groupby('Element').sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %% [markdown]
# Year 2017 has the highest sum of Import Quantity

# %% [markdown]
# ## Question 16

# %% [markdown]
# From the table in question 15, The total number of the sum of Production in 2014 is 1931287.75

# %% [markdown]
# ## Question 17

# %%
data.loc[:, ['Y2018','Element']].groupby('Element').sum()
# Out:
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# Residuals                                 34864.00
# Seed                                      25263.14
# Stock Variation                           20577.91
# Total Population - Both sexes           1140605.00
# ...

# %% [markdown]
# The elements with the highest sum in 2018 is Domestic supply quantity

# %% [markdown]
# ## Question 18

# %% [markdown]
# From the table in question 17 above,the third lowest sum in 2018 is Seed

# %% [markdown]
# ## Question 20

# %%
len(data['Area'].unique())
# Out:
# 49

# %% [markdown]
# The total number of unique countries in the dataset is 49
