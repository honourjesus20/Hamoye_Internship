# %% [markdown]
# <a href="https://colab.research.google.com/github/honourjesus20/Hamoye_Internship/blob/main/my_stage_b_tag_along_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U openpyxl

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f1a08d32-79da-4882-aa0d-da691eb4c6a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f1a08d32-79da-4882-aa0d-da691eb4c6a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving energydata_complete.csv to energydata_complete (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['energydata_complete.csv']))

# %%
df2.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
pd.set_option("display.max_columns",None)

# %%
from sklearn import linear_model as LM

# %%
from pandas.core.common import random_state


simple_linear_reg_df= df2[["T2","T6"]].sample(15, random_state = 42)
simple_linear_reg_df1 =df2[["T2","Appliances"]].sample(15, random_state = 42)
simple_linear_reg_df2 = df2[["T6","Appliances"]].sample(15, random_state = 42)

# %%
sns.regplot(x="T2", y ="T6", data= simple_linear_reg_df)

# %%
sns.regplot(x="T2", y="Appliances", data=simple_linear_reg_df1 )

# %%
sns.regplot(x="T6", y="Appliances", data =simple_linear_reg_df2)

# %%
df2 = df2.drop(columns=["date","lights"])

# %%
df2
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5       RH_5         T6  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
linreg= LinearRegression()
scaler = MinMaxScaler()

# %%
normalized_df = pd.DataFrame(scaler.fit_transform(df2), columns = df2.columns)
normalized_df
# Out:
#        Appliances        T1      RH_1        T2      RH_2        T3      RH_3  \
# 0        0.046729  0.327350  0.566187  0.225345  0.684038  0.215188  0.746066
# 1        0.046729  0.327350  0.541326  0.225345  0.682140  0.215188  0.748871
# 2        0.037383  0.327350  0.530502  0.225345  0.679445  0.215188  0.755569
# 3        0.037383  0.327350  0.524080  0.225345  0.678414  0.215188  0.758685
# 4        0.046729  0.327350  0.531419  0.225345  0.676727  0.215188  0.758685
# ...           ...       ...       ...       ...       ...       ...       ...
# 19730    0.084112  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374
# 19731    0.074766  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178
# 19732    0.242991  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988
# 19733    0.383178  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294
# 19734    0.392523  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062
#
# ...

# %%
feature_df = normalized_df.drop(columns='Appliances')
feature_df
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
target_var= normalized_df["Appliances"]
target_var
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
from sklearn.model_selection import train_test_split as split
x_train, x_test, y_train, y_test=split(feature_df["T2"].values.reshape(-1, 1), feature_df['T6'], train_size=0.3)

# %%
model =linreg.fit(x_train, y_train)
model
# Out:
# LinearRegression()

# %%
x_test
# Out:
# array([[0.2471529 ],
#        [0.3045796 ],
#        [0.08432275],
#        ...,
#        [0.25684517],
#        [0.23915677],
#        [0.44560213]])

# %%
y_test
# Out:
# 9833     0.347305
# 4535     0.227769
# 1114     0.027297
# 2556     0.391937
# 10981    0.412313
#            ...
# 17054    0.608458
# 18580    0.766361
# 8754     0.389900
# 10422    0.362829
# 13256    0.577160
# Name: T6, Length: 13815, dtype: float64

# %%
predicted_values = linreg.predict(x_test)

# %%
round(linreg.score(x_test,y_test),3)
# Out:
# 0.64

# %%
#Question 13

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(y_test,predicted_values)
round(mae, 2)
# Out:
# 0.08

# %%
#Question 14

# %%
ss= y_test - predicted_values
rss = np.sum(np.square(ss))
round(rss,2)
# Out:
# 157.19

# %%
#Quesgtion 15

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.107

# %%
from sklearn. metrics import r2_score
r2_value = r2_score(y_test,predicted_values)
round(r2_value, 3)
# Out:
# 0.64

# %%
#Question 16

# %%
from sklearn import metrics
coefficient = metrics.r2_score(y_test, predicted_values)
round(coefficient,2)
# Out:
# 0.64

# %%
#Question 18

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
#Question 19

# %%
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001)

# %%
X= normalized_df.drop(columns=["Appliances"])
Y= normalized_df['Appliances']

x_train,x_test,y_train, y_test =split(X, Y, test_size=0.3, random_state = 42)
LM1 = LinearRegression()
LM1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = LM1.predict(x_test)

# %%
def get_weights_df(model, feat, col_name):
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ["Features",col_name]
  weights_df[col_name].round(3)
  return weights_df

# %% [markdown]
# Question

# %%
linear_model_weights = get_weights_df(LM1,x_train,'Linear_Model_Weight')
linear_model_weights.sort_values(by='Linear_Model_Weight', ascending=True)
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
predict = ridge_reg.predict(x_test)

# %%
rmse_ridge = np.sqrt(metrics.mean_squared_error(y_test, predict))
rmse_linear=np.sqrt(metrics.mean_squared_error(y_test, predictions))

# %%
round(rmse_ridge,3)
# Out:
# 0.088

# %%
round(rmse_linear, 3)
# Out:
# 0.088

# %%
#Question 20

# %%
lasso_weights= get_weights_df(lasso_reg, x_train,"Lasso_Model_Weights")
lasso_weights[(lasso_weights["Lasso_Model_Weights"]< 0)| (lasso_weights["Lasso_Model_Weights"]> 0)]
# Out:
#      Features  Lasso_Model_Weights
# 0      RH_out            -0.049557
# 1        RH_8            -0.000110
# 24  Windspeed             0.002912
# 25       RH_1             0.017880
#      Features  Lasso_Model_Weights
# 0      RH_out            -0.049557
# 1        RH_8            -0.000110
# 24  Windspeed             0.002912
# 25       RH_1             0.017880
